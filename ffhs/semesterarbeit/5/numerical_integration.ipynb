# %% [markdown]
# Semesterarbeit Teil 5 (Beat Kappert)
# ====================================
#
# Numerische Integration
# ----------------------
#
# ### Trapezregel und Simpsonverfahren ###
#
# In den Funktionen `integrate_trapezoid` und `integrate_simpson` sind die grosse Trapezregel resp. das Simpsonverfahren für die numerische Integration implementiert.
#
# Bei Input `n` teilt das Simpsonverfahren das zu integrierende Intervall in Wirklichkeit in doppelt soviele Stücke auf (2n). Um die Vergleichbarkeit mit der Trapezregel zu bewahren, habe ich deshalb bei Simpson immer die Hälfte der n-Werte genommen im Vergleich zur Trapezregel.
#
# Anstatt einer `for` Schleife wollte ich versuchen, die Sigma Summen funktional zu lösen. Deshalb die Konstrukte mit `sum(list(map...`.
# Zuerst werden die Laufindices für die Summe mit `arange` gewonnen. Mit `map` wird für jeden Index die Funktion aufgerufen, das Resultat in einer Liste gesammelt und schliesslich mit `sum` alle Werte der Liste addiert.
#
# Auch an anderen Stellen des Programms habe ich versucht, mit funktionalem Stil zu arbeiten. Das ist zum Teil Geschmackssache, aber immerhin recht kompakt.
#
# ### Fläche unter Parabel ###
#
# Das Programm stellt zuerst eine einfache Parabel dar und berechnet die Fläche zwischen der Kurve und der x-Achse auf drei Arten:
#
# 1. SymPy ergibt den Referenzwert: 4/3
# 2. Näherung mit grosser Trapezregel
# 3. Näherung mit Simpsonverfahren
#
# ### Torus Volumen ###
#
# Dann wird die Eingabe der beiden Radien `r` und `R` erwartet, welche einen Torus definieren. Mit Return werden vorbelegte Werte übernommen.
#
# Für die Berechnung des Torus Volumens habe ich zwei Rotationskörper verwendet. Das Programm stellt die beiden Flächen dar, welche diesen Rotationskörpern zugrundeliegen.
#
# Diese Formel ergibt einen nach unten geöffneten Halbkreis (habe ich als "konkav" bezeichnet):
#
#     y = sqrt(r**2 - x**2) + R
#
# Die Fläche unter diesem Halbkreis ergibt als Rotationskörper eine Scheibe mit rundem Rand.
#
# Der zweite Rotationskörper entsteht aus dem nach oben geöffneten Halbkreis, welcher den ersten Halbkreis zum Vollkreis ergänzt (habe ich als "konvex" bezeichnet):
#
#     y = - sqrt(r**2 - x**2) + R
#
# Das Volumen des Torus ergibt sich aus Sutraktion des zweiten Rotationskörpers vom ersten.
#
# Auch das Torus Volumen wird mit den drei Verfahren berechnet:
#
# 1. SymPy ergibt den Referenzwert: 19.7392088021787 (für r=0.5 und R=4.0)
# 2. Näherung mit grosser Trapezregel
# 3. Näherung mit Simpsonverfahren
#
# ### Diskussion der Resultate ###
# Anhand des Torus Volumens, mit r=0.5 und R=4.0.
#
# Mich hat erstaunt, wie schnell beide numerischen Verfahren für die Berechnung des Torus Volumens schon ansprechende Resultate ergeben.
# Eine Genauigkeit auf 3 Nachkommastellen (gerundet) finde ich für praktische Zwecke schon gut.
# Diese bekommt man mit der Trapezregel für n=1024 und beim Simpsonverfahren mit n=256 (d.h. 512 Segmente).
#
#     SymPy:           19.7392088021787
#     Trapezoid 1024:  19.738571053402737
#     Simpson 256:     19.73850420297798
#
# Das Simpsonverfahren ist beim Torus Volumen nicht dramatisch besser als die Trapezregel. Bei der Fläche unter der Parabel ist der Unterschied deutlicher. Dort hat das Simpsonverfahren schon mit kleinen Werten für n praktisch sofort eine hohe Genauigkeit.
#
# Einsatz von Python für praxisbezogene Anwendungen
# -------------------------------------------------
#
# Ich habe Python 3 als leicht zugängliche Programmiersprache mit guter Dokumentation und einer riesigen Community kennengelernt.
# Sie ist recht einfach zu erlernen und man findet auf dem Internet leicht Antworten für spezifische Problemstellungen.
# Das Tooling ist hervorragend, mehrere moderne Entwicklungsumgebungen stehen zur Verfügung. Persönlich habe ich meistens Visual Studio Code verwendet, weil ich damit auch beruflich arbeite.
#
# Da Python eine Multiparadigmen-Sprache ist, kann man sowohl prozedural, objektorientiert als auch funktional programmieren. Das ist der Weg, den die meisten modernen Programmiersprachen gehen. Entwickler können so arbeiten, wie sie es angenehm finden bzw. den Stil wählen, welcher am besten zur Aufgabe passt.
#
# Eine Schwäche von Python ist die gegenüber kompilierten Sprachen schlechtere Performance. Die grosse Stärke sind aber die vielen Libraries, wovon manche in nativem Code (typischerweise C) geschrieben sind. Dadurch relativiert sich die Frage nach der Performance sehr, denn die wirklich rechenintensiven Aufgaben werden durch hochoptimierten Code erledigt.
#
# Die naheliegendsten Anwendungen von Python liegen im mathematischen und wissenschaftlichen Bereich. Libraries wie NumPy, SymPy und SciPy ermöglichen die Lösung auch schwieriger mathematischer Probleme, von Analysis bis Statistik. Für mich war vor allem SymPy faszinierend, denn es war das erste CAS, mit welchem ich mich intensiver beschäftigt habe.
#
# Python ist aber universell einsetzbar. Django und Flask sind nur zwei bekannte Frameworks für die Web Entwicklung mit Python. Viele gut zu gebrauchende Libraries machen Python zu einer naheliegenden Wahl, wenn man in einem produktiven Umfeld Utilities schreiben will (inklusive GUI, z.B. mit PyQt oder Tkinter). Mit Pygame steht sogar eine sehr populäre Library für die Spieleprogrammierung zur Verfügung.
#
# Python ist eine hochaktuelle Sprache. Der Verlag "Packt" kommentiert dazu in seiner Entwicklerumfrage "SkillUp 2019":
#
# _"Python is the most in demand language - everyone from JavaScript to C++ developers want to learn it next. Data science and machine learning are driving the popularity of Python."_
#
# Dem stimme ich absolut zu!

# %%
# %matplotlib inline

# %%
'''
Demonstrates two numerical integration methods (trapezoid and Simpson) and compares
them to values calculated with SymPy.
'''
from math import pi
import sympy as sym
import numpy as np
import matplotlib.pyplot as plt


def integrate_trapezoid(f, a, b, n):
    '''
    Numerical integration of definite integral from a to b of function f.
    Uses trapezoid rule (große Trapezregel), dividing the range [a, b]
    into n equal intervals.

    Parameters
    ----------
    f : function
        The function to be integrated.
    a : number
        Lower bound of integral.
    b : number
        Upper bound of integral.
    n : number
        Count of intervals into which [a, b] is divided for approximation.

    Returns
    -------
    number
        Integral as approximated value.
    '''
    x_sigma_sum = np.arange(a, b, (b-a)/n)[1:]
    sigma_sum = sum(list(map(f, x_sigma_sum)))
    return ((f(a) + f(b))/2 + sigma_sum) * (b - a) / n


def integrate_simpson(f, a, b, n):
    '''
    Numerical integration of definite integral from a to b of function f.
    Uses Simpson formula (große Simpsonformel), dividing the range [a, b]
    into n*2 equal intervals.

    Parameters
    ----------
    f : function
        The function to be integrated.
    a : number
        Lower bound of integral.
    b : number
        Upper bound of integral.
    n : number
        Controls precision of approximation. The range [a, b] is divided into 2*n intervals.

    Returns
    -------
    number
        Integral as approximated value.
    '''
    x_odd_indexes = np.arange(a, b, (b-a)/(2*n))[1::2]
    sum_x_odd_indexes = sum(list(map(f, x_odd_indexes)))

    x_even_indexes = np.arange(a, b, (b-a)/(2*n))[0::2][1:]
    sum_x_even_indexes = sum(list(map(f, x_even_indexes)))

    return (f(a) + f(b) + 2*sum_x_even_indexes + 4*sum_x_odd_indexes) * (b - a) / (6*n)


def plot_f(title, f_sympy, f, lower_bound, upper_bound, margin=0):
    '''
    Helper function for plotting.
    '''
    x_axis = np.linspace(lower_bound - margin,
                         upper_bound + margin, int(margin * 100))
    plt.title(title)
    plt.plot(x_axis, f(x_axis), color='blue', linewidth=2, label=str(f_sympy))
    plt.grid(True)
    section = np.linspace(lower_bound, upper_bound, 100)
    plt.fill_between(section, f(section), color='red', alpha=0.2)
    plt.legend()
    return plt


def input_number(prompt, default=1, minimum=0, maximum=1000):
    '''
    Helper function for reading a number from standard input.
    '''
    number_incomplete = True
    while number_incomplete:
        number_string = input(prompt + ' [' + str(default) + ']: ').strip()
        if not number_string:
            number_string = str(default)
        try:
            number_value = float(number_string)
            if number_value < minimum:
                print(number_value, 'is below minimum', minimum)
            elif number_value > maximum:
                print(number_value, 'is above maximum', maximum)
            else:
                number_incomplete = False
        except (ValueError) as bad_number_string:
            print(bad_number_string)
            continue
    return number_value


def parabola(comment, f_integrate, n, f_parabola):
    '''
    Helper function for calculating and printing the definite integral of a parabola.
    '''
    print('{0} {1}: '.format(comment, n),
          f_integrate(f_parabola, -1, 1, n))


def torus(comment, f_integrate, n, f_concave, f_convex):
    '''
    Helper function for calculating and printing the volume of a torus.
    '''
    print('{0} {1}: '.format(comment, n),
          pi * f_integrate(f_concave, -r, r, n)
          - pi * f_integrate(f_convex, -r, r, n))


x = sym.symbols('x')

########################################################################
# A parabola as a simple case for testing.
########################################################################
f_parabola_sympy = -x**2 + 1
f_parabola = sym.lambdify(x, f_parabola_sympy, "numpy")

parabola_integral_sympy = sym.integrate(f_parabola_sympy, (x, -1, 1))

title = 'Area under curve {0} from -1 to 1'.format(f_parabola_sympy)
print(' ')
print(title)
print('-'*len(title))

print('SymPy: ', parabola_integral_sympy)

n_values_trapezoid = [4, 10, 80, 400]
list(map(lambda x: parabola('Parabola Trapezoid', integrate_trapezoid, x, f_parabola),
         n_values_trapezoid))

n_values_simpson = [2, 5, 40, 200]
list(map(lambda x: parabola('Parabola Simpson', integrate_simpson, x, f_parabola),
         n_values_simpson))

plot_f('Area under curve with SymPy: ' +
       str(parabola_integral_sympy), f_parabola_sympy, f_parabola, -1, 1, 0.5)
plt.show()


########################################################################
# Torus volume (solid of revolution)
########################################################################
print(' ')
r = input_number('Enter Torus Minor Radius r', 0.5, 0.1, 10)
R = input_number('Enter Torus Major Radius R', 4, 1, 20)

plt.figure('Two Solids of Revolution for Calculating a Torus Volume')

# First solid of revolution is defined by a concave semicircle.
f_semicircle_concave_sympy = sym.sqrt(r**2 - x**2) + R
f_semicircle_concave = sym.lambdify(x, f_semicircle_concave_sympy, "numpy")

volume_semicircle_concave_sympy = pi * \
    sym.integrate(f_semicircle_concave_sympy**2, (x, -r, r))

plt.subplot(1, 2, 1, title='Semicircle Concave')
plt.axis('equal')
plt.ylim(-0.5, R*1.3)
plot_f('Volume: ' + str(volume_semicircle_concave_sympy),
       f_semicircle_concave_sympy, f_semicircle_concave, -r, r)

# Second solid of revolution is defined by a convex semicircle.
f_semicircle_convex_sympy = -sym.sqrt(r**2 - x**2) + R
f_semicircle_convex = sym.lambdify(x, f_semicircle_convex_sympy, "numpy")

volume_semicircle_convex_sympy = pi * \
    sym.integrate(f_semicircle_convex_sympy**2, (x, -r, r))

plt.subplot(1, 2, 2, title='Semicircle Convex')
plt.axis('equal')
plt.ylim(-0.5, R*1.3)
plot_f('Volume: ' + str(volume_semicircle_convex_sympy),
       f_semicircle_convex_sympy, f_semicircle_convex, -r, r)

title = 'Volume of Torus with r={0} R={1}'.format(r, R)
print(' ')
print(title)
print('-'*len(title))

f_semicircle_concave_squared = sym.lambdify(
    x, f_semicircle_concave_sympy**2, "numpy")
f_semicircle_convex_squared = sym.lambdify(
    x, f_semicircle_convex_sympy**2, "numpy")

print('SymPy: ', volume_semicircle_concave_sympy - volume_semicircle_convex_sympy)

# Calculate and print torus volume with trapezoid method for n from 2^2 to 2^15.
n_values_trapezoid = list(map(lambda x: 2**x, np.arange(2, 16)))  # 2^2 to 2^15
list(map(lambda x: torus('Trapezoid', integrate_trapezoid, x,
                         f_semicircle_concave_squared, f_semicircle_convex_squared),
         n_values_trapezoid))

# Calculate and print torus volume with Simpson method for n from 2^1 to 2^14.
n_values_simpson = list(map(lambda x: 2**x, np.arange(1, 15)))  # 2^1 to 2^14
list(map(lambda x: torus('Simpson', integrate_simpson, x,
                         f_semicircle_concave_squared, f_semicircle_convex_squared),
         n_values_simpson))

plt.show()
# Out:
#
# Area under curve -x**2 + 1 from -1 to 1
# ---------------------------------------
# SymPy:  4/3
# Parabola Trapezoid 4:  1.25
# Parabola Trapezoid 10:  1.32
# Parabola Trapezoid 80:  1.333124999999999
# Parabola Trapezoid 400:  1.3333249999999999
# Parabola Simpson 2:  1.3333333333333333
# Parabola Simpson 5:  1.3333333333333335
# Parabola Simpson 40:  1.3333333333333324
# Parabola Simpson 200:  1.333333333333332
# Enter Torus Minor Radius r [0.5]:
# Enter Torus Major Radius R [4]:
#
# Volume of Torus with r=0.5 R=4.0
# --------------------------------
# SymPy:  19.7392088021787
# Trapezoid 4:  17.16598149258489
# Trapezoid 8:  18.822595201285907
# Trapezoid 16:  19.413906249667207
# Trapezoid 32:  19.62397759788326
# Trapezoid 64:  19.69842947992472
# Trapezoid 128:  19.724784237251548
# Trapezoid 256:  19.734107727858245
# Trapezoid 512:  19.73740508419803
# Trapezoid 1024:  19.738571053402737
# Trapezoid 2048:  19.73898331718859
# Trapezoid 4096:  19.739129080002826
# ...
